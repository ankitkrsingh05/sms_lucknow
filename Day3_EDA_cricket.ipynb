# %%
'''
Understanding of the data
    about the data
        shape
        features
    Descriptive 
        5 point summary
        skewness
        outlier
        missing values
'''

# %%
import pandas as pd
import seaborn as sns

# %%
df_cup = pd.read_csv('champion.csv')

# %%
df_cup.head(10)
# Out:
#    Year        Host  No Of Team   Champion  Runner Up Player Of The Series  \
# 0  1984         UAE           3      India  Sri Lanka      Surinder Khanna
# 1  1986   Sri Lanka           3  Sri Lanka   Pakistan     Arjuna Ranatunga
# 2  1988  Bangladesh           4      India  Sri Lanka         Navjot Sidhu
# 3  1990       India           3      India  Sri Lanka          Not Awarded
# 4  1995         UAE           4      India  Sri Lanka         Navjot Sidhu
# 5  1997   Sri Lanka           4  Sri Lanka      India     Arjuna Ranatunga
# 6  2000  Bangladesh           4   Pakistan  Sri Lanka       Yousuf Youhana
# 7  2004   Sri Lanka           6  Sri Lanka      India    Sanath Jayasuriya
# 8  2008    Pakistan           6  Sri Lanka      India       Ajantha Mendis
# 9  2010   Sri Lanka           4      India  Sri Lanka        Shahid Afridi
#
#   Highest Run Scorer Highest Wicket Taker
# 0    Surinder Khanna         Ravi Shastri
# 1   Arjuna Ranatunga          Abdul Qadir
# ...

# %%
df_batsman = pd.read_csv('batsman_data_odi.csv')

# %%
df_batsman
# Out:
#               Player Name      Country Time Period  Matches  Played  Not Outs  \
# 0          ST Jayasuriya     Sri Lanka   1990-2008       25      24         1
# 1          KC Sangakkara     Sri Lanka   2004-2014       24      23         1
# 2           SR Tendulkar         India   1990-2012       23      21         2
# 3           Shoaib Malik      Pakistan   2000-2018       17      15         3
# 4              RG Sharma         India   2008-2018       22      21         5
# 5            A Ranatunga     Sri Lanka   1984-1997       19      19         6
# 6        Mushfiqur Rahim    Bangladesh   2008-2018       21      21         2
# 7       DPMD Jayawardene     Sri Lanka   2000-2014       28      26         3
# 8               MS Dhoni         India   2008-2018       19      16         6
# 9            PA de Silva     Sri Lanka   1984-2000       24      22         2
# 10           MS Atapattu     Sri Lanka   1997-2004       13      12         2
# ...

# %% [markdown]
# # Basic analysis

# %%
# for the cup

# %%
df_cup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  15 non-null     int64
#  1   Host                  15 non-null     object
#  2   No Of Team            15 non-null     int64
#  3   Champion              15 non-null     object
#  4   Runner Up             15 non-null     object
#  5   Player Of The Series  15 non-null     object
#  6   Highest Run Scorer    15 non-null     object
#  7   Highest Wicket Taker  15 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 1.1+ KB

# %%
df_cup.describe()
# Out:
#               Year  No Of Team
# count    15.000000   15.000000
# mean   2002.933333    4.466667
# std      12.492665    1.125463
# min    1984.000000    3.000000
# 25%    1992.500000    4.000000
# 50%    2004.000000    4.000000
# 75%    2013.000000    5.500000
# max    2022.000000    6.000000

# %%
# step 1 
# Ask questions to the data



# ----------Teams
1. How has the number of teams been over the years? is it increasing descreasing or constant 
    timeseries data
        - line chart - x- year,y- no of teams
        This would help us understand the trend

2. Who has been the champion most number of times,Runner Up,highest wicket taker, Highest Run Scorer,Player Of The Series,
    univariate - categorical
        histgram/countplot , piechart
    - 
# ----------Players
3. Who has been the highest wicket taker, Highest Run Scorer,Player Of The Series,

#-----------Teams and players

# %%
sns.countplot(df_cup.Champion)
# Out:
# <Axes: xlabel='count', ylabel='Champion'>

# %%
# for the batsman

# %%
df_batsman.describe().columns
# Out:
# Index(['Matches', 'Played', 'Not Outs', 'Runs', 'Highest Score',
#        'Batting Average', 'Balls Faced', 'Strike Rate', 'Centuries', 'Fifties',
#        'Ducks', 'Fours', 'Sixes'],
#       dtype='object')

# %%
#multivariate analysis
sns.heatmap(df_batsman[['Matches', 'Played', 'Not Outs', 'Runs', 'Highest Score',
       'Batting Average', 'Balls Faced', 'Strike Rate', 'Centuries', 'Fifties',
       'Ducks', 'Fours', 'Sixes']].corr())
# Out:
# <Axes: >

# %%
df_batsman[['Matches', 'Played', 'Not Outs', 'Runs', 'Highest Score',
       'Batting Average', 'Balls Faced', 'Strike Rate', 'Centuries', 'Fifties',
       'Ducks', 'Fours', 'Sixes']].corr()
# Out:
#                   Matches    Played  Not Outs      Runs  Highest Score  \
# Matches          1.000000  0.981467  0.411487  0.732956       0.144346
# Played           0.981467  1.000000  0.356590  0.750308       0.158916
# Not Outs         0.411487  0.356590  1.000000  0.156531      -0.043623
# Runs             0.732956  0.750308  0.156531  1.000000       0.527009
# Highest Score    0.144346  0.158916 -0.043623  0.527009       1.000000
# Batting Average -0.304198 -0.342138  0.144127 -0.016498       0.243275
# Balls Faced      0.695999  0.713296  0.115895  0.928304       0.413180
# Strike Rate      0.259709  0.262481  0.203155  0.359477       0.400214
# Centuries        0.334328  0.359575 -0.103720  0.750393       0.732513
# Fifties          0.438905  0.438967  0.233299  0.591166       0.058791
# Ducks            0.439973  0.432714  0.186277  0.135149      -0.241614
# Fours            0.613069  0.644863 -0.050467  0.931923       0.499232
# ...

# %%
# bivariate analysis
sns.pairplot(df_batsman[['Matches','Played','Runs','Batting Average']])

# %%
sns.boxplot(df_batsman['Batting Average'])
# Out:
# <Axes: ylabel='Batting Average'>

# %%
# analyze the outlier
cond = df_batsman['Batting Average']> 200
df_batsman.loc[cond]
# Out:
#     Player Name   Country Time Period  Matches  Played  Not Outs  Runs  \
# 48  Fawad Alam   Pakistan   2008-2014        4       3         2   251
#
#     Highest Score  Batting Average  Balls Faced  Strike Rate  Centuries  \
# 48            114            251.0          281        89.32          1
#
#     Fifties  Ducks  Fours  Sixes
# 48        2      0     15      5

# %%
# cat vs num
sns.barplot(data=df_batsman,x='Player Name',y='Matches')
# Out:
# <Axes: xlabel='Player Name', ylabel='Matches'>

# %%
df_batsman.shape
# Out:
# (50, 16)

# %%
df_batsman[df_batsman['Matches']<8]
# Out:
#               Player Name      Country Time Period  Matches  Played  Not Outs  \
# 42         Nasir Jamshed      Pakistan   2008-2012        6       6         2
# 46  Hashmatullah Shahidi   Afghanistan   2018-2018        5       5         1
# 48            Fawad Alam      Pakistan   2008-2014        4       3         2
# 49            Javed Omar    Bangladesh   1995-2004        7       7         1
#
#     Runs  Highest Score  Batting Average  Balls Faced  Strike Rate  Centuries  \
# 42   298            112            74.50          300        99.33          1
# 46   263             97            65.75          364        72.25          0
# 48   251            114           251.00          281        89.32          1
# 49   250             85            41.66          447        55.92          0
#
#     Fifties  Ducks  Fours  Sixes
# 42        3      0     34      4
# 46        3      1     17      0
# 48        2      0     15      5
# 49        3      0     16      1

# %%
df_batsman['Matches'].value_count()
# sns.countplot(df_batsman.Matches.value_count())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/26/w56ybb2s7tb9rmnhvsgnxtz80000gn/T/ipykernel_42956/3777857383.py in ?()
# ----> 1 df_batsman['Matches'].value_count()
#       2 # sns.countplot(df_batsman.Matches.value_count())
#
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'value_count'

# %%
df_batsman.head(10)
# Out:
#          Player Name     Country Time Period  Matches  Played  Not Outs  Runs  \
# 0     ST Jayasuriya    Sri Lanka   1990-2008       25      24         1  1220
# 1     KC Sangakkara    Sri Lanka   2004-2014       24      23         1  1075
# 2      SR Tendulkar        India   1990-2012       23      21         2   971
# 3      Shoaib Malik     Pakistan   2000-2018       17      15         3   786
# 4         RG Sharma        India   2008-2018       22      21         5   745
# 5       A Ranatunga    Sri Lanka   1984-1997       19      19         6   741
# 6   Mushfiqur Rahim   Bangladesh   2008-2018       21      21         2   699
# 7  DPMD Jayawardene    Sri Lanka   2000-2014       28      26         3   674
# 8          MS Dhoni        India   2008-2018       19      16         6   648
# 9       PA de Silva    Sri Lanka   1984-2000       24      22         2   645
#
#    Highest Score  Batting Average  Balls Faced  Strike Rate  Centuries  \
# ...

# %%
# univariate analysis 

# categorical
sns.countplot(df_batsman.Country)
# sns.piechart()
# numerical
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[102], line 5
#       1 # univariate analysis
#       2
#       3 # categorical
#       4 sns.countplot(df_batsman.Country)
# ----> 5 sns.piechart()
#
# AttributeError: module 'seaborn' has no attribute 'piechart'
