# %%
Use map() and lambda to square all elements of a list.

Given a list of strings, use filter() to keep only strings longer than 5 characters.

Use map() to convert a list of temperatures from Celsius to Fahrenheit.

Use reduce() to find the product of all numbers in a list.

From a list of integers, use map() and lambda to convert even numbers to their square and odd numbers to their cube.

# %%
Reverse a string using slicing (no loops).

Extract the middle character(s) of a string using slicing.

Remove every third character from a string.

Check whether a string is a palindrome using slicing.

Rotate a string to the left by k positions using slicing.

# %%
Generate a list of squares of even numbers from 1 to 50 using list comprehension.

Flatten a 2D list using list comprehension.

Create a list of (number, square) pairs for numbers from 1 to 10.

From a sentence, create a list of words that start with a vowel.

Replace negative numbers in a list with 0 using list comprehension.

# %%
Write a program to calculate the sum of each row in a 2D list.

Write code to find the transpose of a matrix.

Find the maximum element in each column of a 2D array.

Add two matrices of the same size.

Check whether a matrix is symmetric.

# %%
Write a recursive function to compute the power of a number.

Write a function that returns all prime numbers up to n.

Write a recursive function to flatten a nested list.

Create a function that accepts a list and returns a dictionary of element frequencies.

# %%
Write a function that accepts another function as an argument and applies it to each element of a list.

Sort a list of tuples based on the second element using lambda.

# %%
Compress a string using character counts (e.g., "aaabb" → "a3b2").

Find all sublists of a list whose sum is zero.
